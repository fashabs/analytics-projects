# %% [markdown]
# #### Installing the snscrape package

# %%
# !pip3 install git+https://github.com/JustAnotherArchivist/snscrape.git

# %%
#Importing necessary library
import snscrape.modules.twitter as sntwitter
import pandas as pd
from datetime import date
import timeit

# %%
# Creating list to append tweet data to
tweets_list1 = []

query  = 'monkeypox OR monkey pox OR #monkeypox OR monkey-pox'
initial_date = "2022-09-29"
start_date = initial_date
until_date = "2022-10-01"

# %%
# Using TwitterSearchScraper to scrape data and append tweets to list

start = timeit.default_timer()

for i,tweet in enumerate(sntwitter.TwitterSearchScraper(f'{query} since:{initial_date} until:{until_date}').get_items()):
    if i>100:
        break
    tweets_list1.append([tweet.date, tweet.id, tweet.content, tweet.user.username, 
                         tweet.likeCount, tweet.replyCount, tweet.retweetCount, 
                         tweet.lang, tweet.source, tweet.hashtags])
    
# Creating a dataframe from the tweets list above
mpox_tweets = pd.DataFrame(tweets_list1, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Like Count', 'Reply Count',
                                                 'RetweetCount','Language', 'Source', 'Hashtags'])
elapsed = timeit.default_timer() - start

print('Execution time ', elapsed, ' seconds')
# Out:
# /var/folders/8s/p2g261dd1tjdybwdlkvch4lh0000gn/T/ipykernel_11371/1259486999.py:8: FutureWarning: content is deprecated, use rawContent instead
#   tweets_list1.append([tweet.date, tweet.id, tweet.content, tweet.user.username,
# Execution time  4.920302501  seconds

# %% [markdown]
# #### write dataframe into csv file

# %%
mpox_tweets.to_csv('monkeypox.csv')
mpox_tweets
# Out:
#                      Datetime             Tweet Id  \
# 0   2022-09-30 23:57:18+00:00  1575998250905047040
# 1   2022-09-30 23:57:07+00:00  1575998207032631296
# 2   2022-09-30 23:55:14+00:00  1575997730500972544
# 3   2022-09-30 23:54:34+00:00  1575997561797689344
# 4   2022-09-30 23:54:01+00:00  1575997424266420224
# ..                        ...                  ...
# 96  2022-09-30 21:09:19+00:00  1575955977417166849
# 97  2022-09-30 21:05:56+00:00  1575955125306535936
# 98  2022-09-30 21:05:02+00:00  1575954898109112323
# 99  2022-09-30 21:04:13+00:00  1575954691808120832
# 100 2022-09-30 21:01:10+00:00  1575953924963581963
#
#                                                   Text        Username  \
# 0    American Government: ‘The #monkeypox virus spr...    johnOkillens
# 1    They stole my sons catalytic converter I hope ...   LordotDragons
# 2    In response to #monkeypox, @POTUS requested th...    LALGBTCenter
# 3    #Enfermeiros infectados após coleta de amostra...     AlagoasReal
# 4                   Monkey pox just up and disappeared       _sewjazzy
# ..                                                 ...             ...
# 96   https://t.co/LSgKMIHyeL #Fauci #MonkeyPox #Dog...    DogFacePonia
# 97   @pbean25 @JudiciaryGOP It’s a reflection of th...   Kevin00264996
# 98   please take monkey pox seriously, look what th...  GOOFYPURPLEGUY
# 99   I just got my second dose of the Monkeypox Vac...  PhillipMartin2
# 100  #Monkeypox can spread through close, sustained...     afrsflorida
#
#      Like Count  Reply Count  RetweetCount Language  \
# 0             0            0             1       en
# 1             6            0             0       en
# 2             7            1             2       en
# 3             1            0             0       pt
# 4             0            0             0       en
# ..          ...          ...           ...      ...
# 96            1            0             0      qme
# 97            0            0             0       en
# 98            4            0             1       en
# 99            0            2             0       en
# 100           0            0             0       en
#
#                                                 Source  \
# 0    <a href="http://twitter.com/#!/download/ipad" ...
# 1    <a href="http://twitter.com/download/iphone" r...
# 2    <a href="https://mobile.twitter.com" rel="nofo...
# 3    <a href="https://mobile.twitter.com" rel="nofo...
# 4    <a href="http://twitter.com/download/iphone" r...
# ..                                                 ...
# 96   <a href="https://mobile.twitter.com" rel="nofo...
# 97   <a href="http://twitter.com/download/iphone" r...
# 98   <a href="https://mobile.twitter.com" rel="nofo...
# 99   <a href="https://mobile.twitter.com" rel="nofo...
# 100  <a href="https://www.hootsuite.com" rel="nofol...
#
#                                               Hashtags
# 0                                          [monkeypox]
# 1                                                 None
# 2                                          [monkeypox]
# 3                             [Enfermeiros, monkeypox]
# 4                                                 None
# ..                                                 ...
# 96   [Fauci, MonkeyPox, DogFacePonia, Cuomo, COVID1...
# 97                                                None
# 98                                                None
# 99   [monkeypox, vaccine, NYC, USA, LGBTQ, BREAKING...
# 100                                        [Monkeypox]
#
# [101 rows x 10 columns]
